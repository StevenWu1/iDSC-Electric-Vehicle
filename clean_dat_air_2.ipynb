# %%
import pandas as pd

# %%
air_quality_2 = pd.read_csv("PM25_C1.csv")
air_quality_2 = air_quality_2.drop(columns=["Unnamed: 0", "index"])
air_quality_2.head(5)
# Out:
#   WHO Country Name City or Locality  Measurement Year  PM2.5 (μg/m3)  \
# 0      Afghanistan            Kabul              2019         119.77
# 1          Albania           Durres              2016          14.32
# 2          Albania            Korce              2015          30.34
# 3          Albania            Korce              2016          28.64
# 4          Albania            Vlore              2019          10.32
#
#    PM25 temporal coverage (%)
# 0                        18.0
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN

# %%
cities = air_quality_2['City or Locality'].unique()
cities
# cities = ['Adelaide']
# Out:
# array(['Kabul', 'Durres', 'Korce', ..., 'Uthungulu', 'Waterberg',
#        'West Coast'], dtype=object)

# %%
df_test = pd.DataFrame(data={"WHO Country Name": ["NA"], "City or Locality": ["NA"], "Measurement Year": ["NA"], "PM2.5 (μg/m3)": ["NA"], "PM25 temporal coverage (%)": ["NA"]})
for city in cities:
    df_current_city = air_quality_2[air_quality_2['City or Locality'] == city]
    replace_value = df_current_city['PM25 temporal coverage (%)'].mean()
    replace_value = round(replace_value, 2)
    df_current_city = df_current_city.fillna(value = replace_value)
    df_test = pd.concat([df_test, df_current_city])

# %%
df_test.to_csv("clean_test.csv")

# %%
df_test.head(10)
# Out:
#        WHO Country Name City or Locality Measurement Year PM2.5 (μg/m3)  \
# 0                    NA               NA               NA            NA
# 0           Afghanistan            Kabul             2019        119.77
# 1               Albania           Durres             2016         14.32
# 2               Albania            Korce             2015         30.34
# 3               Albania            Korce             2016         28.64
# 4               Albania            Vlore             2019         10.32
# 5               Albania            Vrith             2015         13.24
# 6  United Arab Emirates        Abu Dhabi             2017         32.79
# 7  United Arab Emirates        Abu Dhabi             2018         49.13
# 8  United Arab Emirates        Abu Dhabi             2019          44.4
#
#   PM25 temporal coverage (%)
# 0                         NA
# 0                       18.0
# 1                        NaN
# 2                        NaN
# ...
